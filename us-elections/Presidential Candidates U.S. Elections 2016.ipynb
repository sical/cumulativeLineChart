# %% [markdown]
# # Presidential candidates
#
# * Fetch data and merge from various sources
# * Output to visualization projects
# * Metadata from wikipedia

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/rvuillemot/Dropbox/predigy/us-elections2016/data/fields.tsv', 'r', delimiter='\t',encoding='utf-8')

# %%
data.head()
# Out:
#    year         candidate      last party  not announced year-party  \
# 0  1972   George McGovern  McGovern     D            NaN     1972-D
# 1  1972   Eugene McCarthy  McCarthy     D            NaN     1972-D
# 2  1972   Hubert Humphrey  Humphrey     D            NaN     1972-D
# 3  1972    George Wallace   Wallace     D            NaN     1972-D
# 4  1972  Shirley Chisholm  Chisholm     D            NaN     1972-D
#
#              name-party formal announcement withdrawal date  \
# 0   George McGovern - D           1/18/1971            none
# 1   Eugene McCarthy - D          12/17/1971       7/11/1972
# 2   Hubert Humphrey - D           1/10/1972       7/11/1972
# 3    George Wallace - D           1/13/1972            none
# 4  Shirley Chisholm - D           1/25/1972            none
#
#    days in candidacy                        ...                          \
# 0                540                        ...
# 1                207                        ...
# ...

# %%
 f = open('/Users/rvuillemot/Dropbox/predigy/us-elections2016/data/candidates.json', 'r+')
f.write('toto')
# Out:
# 4

# %%
data
# Out:
#      year            candidate       last party  not announced year-party  \
# 0    1972      George McGovern   McGovern     D            NaN     1972-D
# 1    1972      Eugene McCarthy   McCarthy     D            NaN     1972-D
# 2    1972      Hubert Humphrey   Humphrey     D            NaN     1972-D
# 3    1972       George Wallace    Wallace     D            NaN     1972-D
# 4    1972     Shirley Chisholm   Chisholm     D            NaN     1972-D
# 5    1972        Terry Sanford    Sanford     D            NaN     1972-D
# 6    1972        Henry Jackson    Jackson     D            NaN     1972-D
# 7    1972        Edmund Muskie     Muskie     D            NaN     1972-D
# 8    1972         John Lindsay    Lindsay     D            NaN     1972-D
# 9    1972         Wilbur Mills      Mills     D            NaN     1972-D
# 10   1972         Vance Hartke     Hartke     D            NaN     1972-D
# 11   1972            Sam Yorty      Yorty     D            NaN     1972-D
# ...
